# %%
import re

# %%
import pandas

# %%
import os

# %%
entries = os.listdir('prostate disease/')

# %%
entries
# Out:
# ['pubmed_result (1).txt',
#  'pubmed_result(1)(1).txt',
#  'pubmed_result(1).txt',
#  'pubmed_result(10).txt',
#  'pubmed_result(2)(1).txt',
#  'pubmed_result(2).txt',
#  'pubmed_result(3)(1).txt',
#  'pubmed_result(3).txt',
#  'pubmed_result(4).txt',
#  'pubmed_result(5).txt',
#  'pubmed_result(6).txt',
#  'pubmed_result(7).txt',
#  'pubmed_result(8).txt',
#  'pubmed_result(9).txt',
#  'pubmed_result-1.txt',
#  'pubmed_result-10.txt',
#  'pubmed_result-11.txt',
#  'pubmed_result-12.txt',
#  'pubmed_result-13.txt',
#  'pubmed_result-14.txt',
#  'pubmed_result-15.txt',
#  'pubmed_result-16.txt',
#  'pubmed_result-17.txt',
#  'pubmed_result-18.txt',
#  'pubmed_result-19.txt',
#  'pubmed_result-2.txt',
#  'pubmed_result-20.txt',
#  'pubmed_result-21.txt',
#  'pubmed_result-22.txt',
#  'pubmed_result-23.txt',
#  'pubmed_result-24.txt',
#  'pubmed_result-25.txt',
#  'pubmed_result-26.txt',
#  'pubmed_result-27.txt',
#  'pubmed_result-28.txt',
#  'pubmed_result-29.txt',
#  'pubmed_result-3.txt',
#  'pubmed_result-30.txt',
#  'pubmed_result-31.txt',
#  'pubmed_result-32.txt',
#  'pubmed_result-33.txt',
#  'pubmed_result-34.txt',
#  'pubmed_result-35.txt',
#  'pubmed_result-36.txt',
#  'pubmed_result-37.txt',
#  'pubmed_result-38.txt',
#  'pubmed_result-39.txt',
#  'pubmed_result-4.txt',
#  'pubmed_result-40.txt',
#  'pubmed_result-5.txt',
#  'pubmed_result-6.txt',
#  'pubmed_result-7.txt',
#  'pubmed_result-8.txt',
#  'pubmed_result-9.txt',
#  'pubmed_result.txt']

# %%
dictiongene=['DESIGN', 'EXPERIMENTAL', 'HPC','DOI','DNA','CONFLICTS', 'HJF', 'INTEREST', 'LNC','ABSTRACT', 'TRUNCATED', 'WORDS','PCR', 'AND','ATM','RNA','MEDLINE','MATERIALS', 'PURPOSE', 'USA','METHODS','LIMITATION','RESULTS','BACKGROUND','CONCLUSION','CONCLUSIONS','PMID','INTRODUCTION','METHODOLOGY','PMCID']
data=[]
for i in range(len(entries)):
    path='prostate disease/'+entries[i]
    with open(path) as f:
        x=list(re.findall("[A-Z][A-Z0-9-]+",f.read()))
        l1=re.findall("C[0-9]+",f.read())
        if l1!= []:
            x.append(l1)
        l2=re.findall("f[0-9]+",f.read())
        if l2!=[]:
            x.append(l2)
        finx=[]
        x=set(x)
        for i in x:
            if i not in dictiongene and len(i) is not 2:
                finx.append(i)
        finx.sort()
        data.append(finx)
        
        
print(data)
# Out:
# [['BRCA1', 'BRCA2', 'BRIP1', 'CHEK2', 'FANCJ', 'FANCN', 'FANCO', 'GWAS', 'PALB2', 'PTEN', 'RAD51C', 'TP53', 'USC'], ['APC', 'BRCA1', 'CIP1', 'DCC', 'ISH', 'LOE', 'LOH', 'LOX', 'MCC', 'MDM2', 'RFLP', 'RT-PCR', 'SRS', 'SSCP', 'VNTR', 'WAF1'], ['CYP17', 'D10S222', 'LOD', 'P450'], ['IL-2', 'IL-2RB', 'PMC6807315'], ['ANT', 'CEBPB', 'EGR1', 'HIF-', 'PMC6035043', 'STAT5'], [], [], ['BRCA2', 'CCR-06-2164'], ['BRCA2', 'EPI-08-0556', 'NIH', 'PMC2562346'], ['CGEMS', 'COX7A2', 'EPI-08-0434', 'MTRR', 'NDUFA9', 'NDUFB9', 'NDUFS2', 'PMC2750891', 'SNP'], [], ['APC', 'BJU', 'CD44', 'CDH13', 'EDNRB', 'GSTP1', 'PSA', 'PTGS2', 'RASS1', 'T1G1'], ['A1298C', 'C677T', 'MTHFR'], ['D980-5', 'DDPC', 'PMC3013759', 'X17'], ['PMC6996919', 'PMEAP1-', 'PMEPA1', 'PMEPA1-', 'PMPEA1-', 'SE-NAP', 'TCGA', 'TGF-'], ['N141', 'N23', 'N44', 'PSP94'], ['PCR-SSCP', 'PMC1968625'], ['P53', 'PC10', 'PCNA', 'RFLP'], ['ACT--', 'GCT'], ['MDM-2', 'PMC1887392'], ['PCR-SSCP', 'PMC5919581'], ['HLH', 'MAD', 'MXI1'], [], ['BRCA1', 'D17S250', 'D17S579', 'D17S588', 'D17S855', 'D17S856'], ['MXI1'], ['A----G', 'G----T', 'TSU-PR1'], ['NEJM199505253322101'], ['AT6', 'KAI1'], ['ER-', 'HER2', 'RB-1'], ['CREF-T', 'PMC41412', 'PTI-1'], ['SRD5A2'], ['AID-PROS6', 'ASO', 'AT-1', 'AT-3', 'R-3327', 'SICI'], [], ['CAT', 'CGT'], ['CMV', 'CMV-GM-CSF', 'CMV-IL-2', 'CWR22', 'GM-CSF', 'IL-2', 'IMPLICATIONS', 'PSA'], ['APC', 'PCR-SSCP'], [], ['P53', 'PCR-SSCP', 'PMC2074577', 'SSCP'], ['BPH', 'CAB', 'NM23', 'RT-PCR'], ['AML', 'DNA-', 'EVI-1', 'FISH', 'PMC2074868', 'RT-PCR'], ['MTS1', 'SSCP'], ['AID-PROS8', 'DU145', 'GBX2', 'HOXA', 'PC-3', 'RT-PCR', 'SICI', 'TSU-PR1'], ['BRCA2', 'CAPAN-1'], ['PTI-1', 'RT-PCR', 'UTR', 'UTR-'], ['CDKN2', 'MTS1'], ['GAC', 'TAC'], ['ETS-2', 'NSE', 'SEF2'], ['P53'], ['CDKI', 'CDKN2', 'INK4', 'INK4A', 'INK4B', 'INK4C', 'INK4D', 'MTS1', 'MTS2', 'PCR-SSCP', 'UCLA'], ['C57BL', 'TGF-'], ['B-2', 'DU-145', 'PC-3', 'PSA'], ['DNA-PCR'], ['BPH', 'DU-145', 'RT-PCR', 'ZFX', 'ZFY'], ['SSCP'], ['MMP-1', 'PCR-RFLP']]

# %%
import pandas as pd
genedata=[]
for i in range(len(data)):
    l=[]
    l.append('R'+str(i+1))
    l.append(data[i])
    genedata.append(l)
#print(genedata)
df=pd.DataFrame(genedata,columns=["record no","gene symbols"])
df
# Out:
#    record no                                       gene symbols
# 0         R1  [BRCA1, BRCA2, BRIP1, CHEK2, FANCJ, FANCN, FAN...
# 1         R2  [APC, BRCA1, CIP1, DCC, ISH, LOE, LOH, LOX, MC...
# 2         R3                        [CYP17, D10S222, LOD, P450]
# 3         R4                         [IL-2, IL-2RB, PMC6807315]
# 4         R5        [ANT, CEBPB, EGR1, HIF-, PMC6035043, STAT5]
# 5         R6                                                 []
# 6         R7                                                 []
# 7         R8                               [BRCA2, CCR-06-2164]
# 8         R9              [BRCA2, EPI-08-0556, NIH, PMC2562346]
# 9        R10  [CGEMS, COX7A2, EPI-08-0434, MTRR, NDUFA9, NDU...
# 10       R11                                                 []
# 11       R12  [APC, BJU, CD44, CDH13, EDNRB, GSTP1, PSA, PTG...
# 12       R13                             [A1298C, C677T, MTHFR]
# 13       R14                    [D980-5, DDPC, PMC3013759, X17]
# 14       R15  [PMC6996919, PMEAP1-, PMEPA1, PMEPA1-, PMPEA1-...
# 15       R16                            [N141, N23, N44, PSP94]
# 16       R17                             [PCR-SSCP, PMC1968625]
# 17       R18                            [P53, PC10, PCNA, RFLP]
# 18       R19                                       [ACT--, GCT]
# 19       R20                                [MDM-2, PMC1887392]
# 20       R21                             [PCR-SSCP, PMC5919581]
# 21       R22                                   [HLH, MAD, MXI1]
# 22       R23                                                 []
# 23       R24  [BRCA1, D17S250, D17S579, D17S588, D17S855, D1...
# 24       R25                                             [MXI1]
# 25       R26                          [A----G, G----T, TSU-PR1]
# 26       R27                              [NEJM199505253322101]
# 27       R28                                        [AT6, KAI1]
# 28       R29                                  [ER-, HER2, RB-1]
# 29       R30                          [CREF-T, PMC41412, PTI-1]
# 30       R31                                           [SRD5A2]
# 31       R32         [AID-PROS6, ASO, AT-1, AT-3, R-3327, SICI]
# 32       R33                                                 []
# 33       R34                                         [CAT, CGT]
# 34       R35  [CMV, CMV-GM-CSF, CMV-IL-2, CWR22, GM-CSF, IL-...
# 35       R36                                    [APC, PCR-SSCP]
# 36       R37                                                 []
# 37       R38                  [P53, PCR-SSCP, PMC2074577, SSCP]
# 38       R39                           [BPH, CAB, NM23, RT-PCR]
# 39       R40       [AML, DNA-, EVI-1, FISH, PMC2074868, RT-PCR]
# 40       R41                                       [MTS1, SSCP]
# 41       R42  [AID-PROS8, DU145, GBX2, HOXA, PC-3, RT-PCR, S...
# 42       R43                                   [BRCA2, CAPAN-1]
# 43       R44                         [PTI-1, RT-PCR, UTR, UTR-]
# 44       R45                                      [CDKN2, MTS1]
# 45       R46                                         [GAC, TAC]
# 46       R47                                 [ETS-2, NSE, SEF2]
# 47       R48                                              [P53]
# 48       R49  [CDKI, CDKN2, INK4, INK4A, INK4B, INK4C, INK4D...
# 49       R50                                      [C57BL, TGF-]
# 50       R51                           [B-2, DU-145, PC-3, PSA]
# 51       R52                                          [DNA-PCR]
# 52       R53                    [BPH, DU-145, RT-PCR, ZFX, ZFY]
# 53       R54                                             [SSCP]
# 54       R55                                  [MMP-1, PCR-RFLP]

# %%
def createC1(data):
    """
    Create a list of unique items in transaction data.
    Represent each item as a set of length 1.
    """
    C1 = []
    for transaction in data:
        for item in transaction:
            if not [item] in C1:
                C1.append([item])
    C1.sort()
    
    # create a set for each item in C1
    return [set(x) for x in C1]
def createCk(Lk, k):
    """
    Create a list of candidates of length k.
    
    Arguments:
       Lk: a list of frequent itemsets
       k: the size of the itemsets
    
    """
    cand_list = []
    len_Lk = len(Lk)
    
    # join sets if first k-2 items are equal
    for i in range(len_Lk):
        for j in range(i+1, len_Lk):
            L1 = list(Lk[i])[:k-2]
            L2 = list(Lk[j])[:k-2]
            L1.sort()
            L2.sort()
            if L1==L2:
                cand_list.append(Lk[i] | Lk[j])
    
    return cand_list

# %%
def scanD(data, Ck, min_support):
    """
    Scan through transaction data and return a list of candidates that meet
    the support threshold, and support data about the current candidates.
    
    Arguments:
       data: data set,
       Ck: a list of candidate sets
       min_support: the minimum support
    """
    count = {}
    for transaction in data:
        tr = set(transaction)
        for candidate in Ck:
            if candidate.issubset(tr):
                can = frozenset(candidate)
                if can not in count:
                    count[can] = 1
                else:
                    count[can] += 1
                    num_items = float(len(D))
    
    cand_list = []
    support_data = {}
    
    # calculate support for every itemset
    for key in count:
        support = count[key]/num_items
        
        # If the support meets the minimum support requirements, 
        # add it to the list of itemsets.
        if support >= min_support:
            cand_list.insert(0, key)
        support_data[key] = support
    
    return cand_list, support_data

# %%
min_support = 0.02

# %%
C1 = createC1(data)
C1
# Out:
# [{'A----G'},
#  {'A1298C'},
#  {'ACT--'},
#  {'AID-PROS6'},
#  {'AID-PROS8'},
#  {'AML'},
#  {'ANT'},
#  {'APC'},
#  {'ASO'},
#  {'AT-1'},
#  {'AT-3'},
#  {'AT6'},
#  {'B-2'},
#  {'BJU'},
#  {'BPH'},
#  {'BRCA1'},
#  {'BRCA2'},
#  {'BRIP1'},
#  {'C57BL'},
#  {'C677T'},
#  {'CAB'},
#  {'CAPAN-1'},
#  {'CAT'},
#  {'CCR-06-2164'},
#  {'CD44'},
#  {'CDH13'},
#  {'CDKI'},
#  {'CDKN2'},
#  {'CEBPB'},
#  {'CGEMS'},
#  {'CGT'},
#  {'CHEK2'},
#  {'CIP1'},
#  {'CMV'},
#  {'CMV-GM-CSF'},
#  {'CMV-IL-2'},
#  {'COX7A2'},
#  {'CREF-T'},
#  {'CWR22'},
#  {'CYP17'},
#  {'D10S222'},
#  {'D17S250'},
#  {'D17S579'},
#  {'D17S588'},
#  {'D17S855'},
#  {'D17S856'},
#  {'D980-5'},
#  {'DCC'},
#  {'DDPC'},
#  {'DNA-'},
#  {'DNA-PCR'},
#  {'DU-145'},
#  {'DU145'},
#  {'EDNRB'},
#  {'EGR1'},
#  {'EPI-08-0434'},
#  {'EPI-08-0556'},
#  {'ER-'},
#  {'ETS-2'},
#  {'EVI-1'},
#  {'FANCJ'},
#  {'FANCN'},
#  {'FANCO'},
#  {'FISH'},
#  {'G----T'},
#  {'GAC'},
#  {'GBX2'},
#  {'GCT'},
#  {'GM-CSF'},
#  {'GSTP1'},
#  {'GWAS'},
#  {'HER2'},
#  {'HIF-'},
#  {'HLH'},
#  {'HOXA'},
#  {'IL-2'},
#  {'IL-2RB'},
#  {'IMPLICATIONS'},
#  {'INK4'},
#  {'INK4A'},
#  {'INK4B'},
#  {'INK4C'},
#  {'INK4D'},
#  {'ISH'},
#  {'KAI1'},
#  {'LOD'},
#  {'LOE'},
#  {'LOH'},
#  {'LOX'},
#  {'MAD'},
#  {'MCC'},
#  {'MDM-2'},
#  {'MDM2'},
#  {'MMP-1'},
#  {'MTHFR'},
#  {'MTRR'},
#  {'MTS1'},
#  {'MTS2'},
#  {'MXI1'},
#  {'N141'},
#  {'N23'},
#  {'N44'},
#  {'NDUFA9'},
#  {'NDUFB9'},
#  {'NDUFS2'},
#  {'NEJM199505253322101'},
#  {'NIH'},
#  {'NM23'},
#  {'NSE'},
#  {'P450'},
#  {'P53'},
#  {'PALB2'},
#  {'PC-3'},
#  {'PC10'},
#  {'PCNA'},
#  {'PCR-RFLP'},
#  {'PCR-SSCP'},
#  {'PMC1887392'},
#  {'PMC1968625'},
#  {'PMC2074577'},
#  {'PMC2074868'},
#  {'PMC2562346'},
#  {'PMC2750891'},
#  {'PMC3013759'},
#  {'PMC41412'},
#  {'PMC5919581'},
#  {'PMC6035043'},
#  {'PMC6807315'},
#  {'PMC6996919'},
#  {'PMEAP1-'},
#  {'PMEPA1'},
#  {'PMEPA1-'},
#  {'PMPEA1-'},
#  {'PSA'},
#  {'PSP94'},
#  {'PTEN'},
#  {'PTGS2'},
#  {'PTI-1'},
#  {'R-3327'},
#  {'RAD51C'},
#  {'RASS1'},
#  {'RB-1'},
#  {'RFLP'},
#  {'RT-PCR'},
#  {'SE-NAP'},
#  {'SEF2'},
#  {'SICI'},
#  {'SNP'},
#  {'SRD5A2'},
#  {'SRS'},
#  {'SSCP'},
#  {'STAT5'},
#  {'T1G1'},
#  {'TAC'},
#  {'TCGA'},
#  {'TGF-'},
#  {'TP53'},
#  {'TSU-PR1'},
#  {'UCLA'},
#  {'USC'},
#  {'UTR'},
#  {'UTR-'},
#  {'VNTR'},
#  {'WAF1'},
#  {'X17'},
#  {'ZFX'},
#  {'ZFY'}]

# %%
D = list(map(set, data))
D
# Out:
# [{'BRCA1',
#   'BRCA2',
#   'BRIP1',
#   'CHEK2',
#   'FANCJ',
#   'FANCN',
#   'FANCO',
#   'GWAS',
#   'PALB2',
#   'PTEN',
#   'RAD51C',
#   'TP53',
#   'USC'},
#  {'APC',
#   'BRCA1',
#   'CIP1',
#   'DCC',
#   'ISH',
#   'LOE',
#   'LOH',
#   'LOX',
#   'MCC',
#   'MDM2',
#   'RFLP',
#   'RT-PCR',
#   'SRS',
#   'SSCP',
#   'VNTR',
#   'WAF1'},
#  {'CYP17', 'D10S222', 'LOD', 'P450'},
#  {'IL-2', 'IL-2RB', 'PMC6807315'},
#  {'ANT', 'CEBPB', 'EGR1', 'HIF-', 'PMC6035043', 'STAT5'},
#  set(),
#  set(),
#  {'BRCA2', 'CCR-06-2164'},
#  {'BRCA2', 'EPI-08-0556', 'NIH', 'PMC2562346'},
#  {'CGEMS',
#   'COX7A2',
#   'EPI-08-0434',
#   'MTRR',
#   'NDUFA9',
#   'NDUFB9',
#   'NDUFS2',
#   'PMC2750891',
#   'SNP'},
#  set(),
#  {'APC',
#   'BJU',
#   'CD44',
#   'CDH13',
#   'EDNRB',
#   'GSTP1',
#   'PSA',
#   'PTGS2',
#   'RASS1',
#   'T1G1'},
#  {'A1298C', 'C677T', 'MTHFR'},
#  {'D980-5', 'DDPC', 'PMC3013759', 'X17'},
#  {'PMC6996919',
#   'PMEAP1-',
#   'PMEPA1',
#   'PMEPA1-',
#   'PMPEA1-',
#   'SE-NAP',
#   'TCGA',
#   'TGF-'},
#  {'N141', 'N23', 'N44', 'PSP94'},
#  {'PCR-SSCP', 'PMC1968625'},
#  {'P53', 'PC10', 'PCNA', 'RFLP'},
#  {'ACT--', 'GCT'},
#  {'MDM-2', 'PMC1887392'},
#  {'PCR-SSCP', 'PMC5919581'},
#  {'HLH', 'MAD', 'MXI1'},
#  set(),
#  {'BRCA1', 'D17S250', 'D17S579', 'D17S588', 'D17S855', 'D17S856'},
#  {'MXI1'},
#  {'A----G', 'G----T', 'TSU-PR1'},
#  {'NEJM199505253322101'},
#  {'AT6', 'KAI1'},
#  {'ER-', 'HER2', 'RB-1'},
#  {'CREF-T', 'PMC41412', 'PTI-1'},
#  {'SRD5A2'},
#  {'AID-PROS6', 'ASO', 'AT-1', 'AT-3', 'R-3327', 'SICI'},
#  set(),
#  {'CAT', 'CGT'},
#  {'CMV',
#   'CMV-GM-CSF',
#   'CMV-IL-2',
#   'CWR22',
#   'GM-CSF',
#   'IL-2',
#   'IMPLICATIONS',
#   'PSA'},
#  {'APC', 'PCR-SSCP'},
#  set(),
#  {'P53', 'PCR-SSCP', 'PMC2074577', 'SSCP'},
#  {'BPH', 'CAB', 'NM23', 'RT-PCR'},
#  {'AML', 'DNA-', 'EVI-1', 'FISH', 'PMC2074868', 'RT-PCR'},
#  {'MTS1', 'SSCP'},
#  {'AID-PROS8', 'DU145', 'GBX2', 'HOXA', 'PC-3', 'RT-PCR', 'SICI', 'TSU-PR1'},
#  {'BRCA2', 'CAPAN-1'},
#  {'PTI-1', 'RT-PCR', 'UTR', 'UTR-'},
#  {'CDKN2', 'MTS1'},
#  {'GAC', 'TAC'},
#  {'ETS-2', 'NSE', 'SEF2'},
#  {'P53'},
#  {'CDKI',
#   'CDKN2',
#   'INK4',
#   'INK4A',
#   'INK4B',
#   'INK4C',
#   'INK4D',
#   'MTS1',
#   'MTS2',
#   'PCR-SSCP',
#   'UCLA'},
#  {'C57BL', 'TGF-'},
#  {'B-2', 'DU-145', 'PC-3', 'PSA'},
#  {'DNA-PCR'},
#  {'BPH', 'DU-145', 'RT-PCR', 'ZFX', 'ZFY'},
#  {'SSCP'},
#  {'MMP-1', 'PCR-RFLP'}]

# %%
L1, support_data1 = scanD(D, C1, min_support)

# %%
L1
# Out:
# [frozenset({'DU-145'}),
#  frozenset({'CDKN2'}),
#  frozenset({'PC-3'}),
#  frozenset({'MTS1'}),
#  frozenset({'BPH'}),
#  frozenset({'SICI'}),
#  frozenset({'PTI-1'}),
#  frozenset({'TSU-PR1'}),
#  frozenset({'MXI1'}),
#  frozenset({'P53'}),
#  frozenset({'PCR-SSCP'}),
#  frozenset({'TGF-'}),
#  frozenset({'PSA'}),
#  frozenset({'IL-2'}),
#  frozenset({'SSCP'}),
#  frozenset({'RT-PCR'}),
#  frozenset({'RFLP'}),
#  frozenset({'APC'}),
#  frozenset({'BRCA2'}),
#  frozenset({'BRCA1'})]

# %%
support_data1
# Out:
# {frozenset({'BRCA1'}): 0.05454545454545454,
#  frozenset({'BRCA2'}): 0.07272727272727272,
#  frozenset({'BRIP1'}): 0.01818181818181818,
#  frozenset({'CHEK2'}): 0.01818181818181818,
#  frozenset({'FANCJ'}): 0.01818181818181818,
#  frozenset({'FANCN'}): 0.01818181818181818,
#  frozenset({'FANCO'}): 0.01818181818181818,
#  frozenset({'GWAS'}): 0.01818181818181818,
#  frozenset({'PALB2'}): 0.01818181818181818,
#  frozenset({'PTEN'}): 0.01818181818181818,
#  frozenset({'RAD51C'}): 0.01818181818181818,
#  frozenset({'TP53'}): 0.01818181818181818,
#  frozenset({'USC'}): 0.01818181818181818,
#  frozenset({'APC'}): 0.05454545454545454,
#  frozenset({'CIP1'}): 0.01818181818181818,
#  frozenset({'DCC'}): 0.01818181818181818,
#  frozenset({'ISH'}): 0.01818181818181818,
#  frozenset({'LOE'}): 0.01818181818181818,
#  frozenset({'LOH'}): 0.01818181818181818,
#  frozenset({'LOX'}): 0.01818181818181818,
#  frozenset({'MCC'}): 0.01818181818181818,
#  frozenset({'MDM2'}): 0.01818181818181818,
#  frozenset({'RFLP'}): 0.03636363636363636,
#  frozenset({'RT-PCR'}): 0.10909090909090909,
#  frozenset({'SRS'}): 0.01818181818181818,
#  frozenset({'SSCP'}): 0.07272727272727272,
#  frozenset({'VNTR'}): 0.01818181818181818,
#  frozenset({'WAF1'}): 0.01818181818181818,
#  frozenset({'CYP17'}): 0.01818181818181818,
#  frozenset({'D10S222'}): 0.01818181818181818,
#  frozenset({'LOD'}): 0.01818181818181818,
#  frozenset({'P450'}): 0.01818181818181818,
#  frozenset({'IL-2'}): 0.03636363636363636,
#  frozenset({'IL-2RB'}): 0.01818181818181818,
#  frozenset({'PMC6807315'}): 0.01818181818181818,
#  frozenset({'ANT'}): 0.01818181818181818,
#  frozenset({'CEBPB'}): 0.01818181818181818,
#  frozenset({'EGR1'}): 0.01818181818181818,
#  frozenset({'HIF-'}): 0.01818181818181818,
#  frozenset({'PMC6035043'}): 0.01818181818181818,
#  frozenset({'STAT5'}): 0.01818181818181818,
#  frozenset({'CCR-06-2164'}): 0.01818181818181818,
#  frozenset({'EPI-08-0556'}): 0.01818181818181818,
#  frozenset({'NIH'}): 0.01818181818181818,
#  frozenset({'PMC2562346'}): 0.01818181818181818,
#  frozenset({'CGEMS'}): 0.01818181818181818,
#  frozenset({'COX7A2'}): 0.01818181818181818,
#  frozenset({'EPI-08-0434'}): 0.01818181818181818,
#  frozenset({'MTRR'}): 0.01818181818181818,
#  frozenset({'NDUFA9'}): 0.01818181818181818,
#  frozenset({'NDUFB9'}): 0.01818181818181818,
#  frozenset({'NDUFS2'}): 0.01818181818181818,
#  frozenset({'PMC2750891'}): 0.01818181818181818,
#  frozenset({'SNP'}): 0.01818181818181818,
#  frozenset({'BJU'}): 0.01818181818181818,
#  frozenset({'CD44'}): 0.01818181818181818,
#  frozenset({'CDH13'}): 0.01818181818181818,
#  frozenset({'EDNRB'}): 0.01818181818181818,
#  frozenset({'GSTP1'}): 0.01818181818181818,
#  frozenset({'PSA'}): 0.05454545454545454,
#  frozenset({'PTGS2'}): 0.01818181818181818,
#  frozenset({'RASS1'}): 0.01818181818181818,
#  frozenset({'T1G1'}): 0.01818181818181818,
#  frozenset({'A1298C'}): 0.01818181818181818,
#  frozenset({'C677T'}): 0.01818181818181818,
#  frozenset({'MTHFR'}): 0.01818181818181818,
#  frozenset({'D980-5'}): 0.01818181818181818,
#  frozenset({'DDPC'}): 0.01818181818181818,
#  frozenset({'PMC3013759'}): 0.01818181818181818,
#  frozenset({'X17'}): 0.01818181818181818,
#  frozenset({'PMC6996919'}): 0.01818181818181818,
#  frozenset({'PMEAP1-'}): 0.01818181818181818,
#  frozenset({'PMEPA1'}): 0.01818181818181818,
#  frozenset({'PMEPA1-'}): 0.01818181818181818,
#  frozenset({'PMPEA1-'}): 0.01818181818181818,
#  frozenset({'SE-NAP'}): 0.01818181818181818,
#  frozenset({'TCGA'}): 0.01818181818181818,
#  frozenset({'TGF-'}): 0.03636363636363636,
#  frozenset({'N141'}): 0.01818181818181818,
#  frozenset({'N23'}): 0.01818181818181818,
#  frozenset({'N44'}): 0.01818181818181818,
#  frozenset({'PSP94'}): 0.01818181818181818,
#  frozenset({'PCR-SSCP'}): 0.09090909090909091,
#  frozenset({'PMC1968625'}): 0.01818181818181818,
#  frozenset({'P53'}): 0.05454545454545454,
#  frozenset({'PC10'}): 0.01818181818181818,
#  frozenset({'PCNA'}): 0.01818181818181818,
#  frozenset({'ACT--'}): 0.01818181818181818,
#  frozenset({'GCT'}): 0.01818181818181818,
#  frozenset({'MDM-2'}): 0.01818181818181818,
#  frozenset({'PMC1887392'}): 0.01818181818181818,
#  frozenset({'PMC5919581'}): 0.01818181818181818,
#  frozenset({'HLH'}): 0.01818181818181818,
#  frozenset({'MAD'}): 0.01818181818181818,
#  frozenset({'MXI1'}): 0.03636363636363636,
#  frozenset({'D17S250'}): 0.01818181818181818,
#  frozenset({'D17S579'}): 0.01818181818181818,
#  frozenset({'D17S588'}): 0.01818181818181818,
#  frozenset({'D17S855'}): 0.01818181818181818,
#  frozenset({'D17S856'}): 0.01818181818181818,
#  frozenset({'A----G'}): 0.01818181818181818,
#  frozenset({'G----T'}): 0.01818181818181818,
#  frozenset({'TSU-PR1'}): 0.03636363636363636,
#  frozenset({'NEJM199505253322101'}): 0.01818181818181818,
#  frozenset({'AT6'}): 0.01818181818181818,
#  frozenset({'KAI1'}): 0.01818181818181818,
#  frozenset({'ER-'}): 0.01818181818181818,
#  frozenset({'HER2'}): 0.01818181818181818,
#  frozenset({'RB-1'}): 0.01818181818181818,
#  frozenset({'CREF-T'}): 0.01818181818181818,
#  frozenset({'PMC41412'}): 0.01818181818181818,
#  frozenset({'PTI-1'}): 0.03636363636363636,
#  frozenset({'SRD5A2'}): 0.01818181818181818,
#  frozenset({'AID-PROS6'}): 0.01818181818181818,
#  frozenset({'ASO'}): 0.01818181818181818,
#  frozenset({'AT-1'}): 0.01818181818181818,
#  frozenset({'AT-3'}): 0.01818181818181818,
#  frozenset({'R-3327'}): 0.01818181818181818,
#  frozenset({'SICI'}): 0.03636363636363636,
#  frozenset({'CAT'}): 0.01818181818181818,
#  frozenset({'CGT'}): 0.01818181818181818,
#  frozenset({'CMV'}): 0.01818181818181818,
#  frozenset({'CMV-GM-CSF'}): 0.01818181818181818,
#  frozenset({'CMV-IL-2'}): 0.01818181818181818,
#  frozenset({'CWR22'}): 0.01818181818181818,
#  frozenset({'GM-CSF'}): 0.01818181818181818,
#  frozenset({'IMPLICATIONS'}): 0.01818181818181818,
#  frozenset({'PMC2074577'}): 0.01818181818181818,
#  frozenset({'BPH'}): 0.03636363636363636,
#  frozenset({'CAB'}): 0.01818181818181818,
#  frozenset({'NM23'}): 0.01818181818181818,
#  frozenset({'AML'}): 0.01818181818181818,
#  frozenset({'DNA-'}): 0.01818181818181818,
#  frozenset({'EVI-1'}): 0.01818181818181818,
#  frozenset({'FISH'}): 0.01818181818181818,
#  frozenset({'PMC2074868'}): 0.01818181818181818,
#  frozenset({'MTS1'}): 0.05454545454545454,
#  frozenset({'AID-PROS8'}): 0.01818181818181818,
#  frozenset({'DU145'}): 0.01818181818181818,
#  frozenset({'GBX2'}): 0.01818181818181818,
#  frozenset({'HOXA'}): 0.01818181818181818,
#  frozenset({'PC-3'}): 0.03636363636363636,
#  frozenset({'CAPAN-1'}): 0.01818181818181818,
#  frozenset({'UTR'}): 0.01818181818181818,
#  frozenset({'UTR-'}): 0.01818181818181818,
#  frozenset({'CDKN2'}): 0.03636363636363636,
#  frozenset({'GAC'}): 0.01818181818181818,
#  frozenset({'TAC'}): 0.01818181818181818,
#  frozenset({'ETS-2'}): 0.01818181818181818,
#  frozenset({'NSE'}): 0.01818181818181818,
#  frozenset({'SEF2'}): 0.01818181818181818,
#  frozenset({'CDKI'}): 0.01818181818181818,
#  frozenset({'INK4'}): 0.01818181818181818,
#  frozenset({'INK4A'}): 0.01818181818181818,
#  frozenset({'INK4B'}): 0.01818181818181818,
#  frozenset({'INK4C'}): 0.01818181818181818,
#  frozenset({'INK4D'}): 0.01818181818181818,
#  frozenset({'MTS2'}): 0.01818181818181818,
#  frozenset({'UCLA'}): 0.01818181818181818,
#  frozenset({'C57BL'}): 0.01818181818181818,
#  frozenset({'B-2'}): 0.01818181818181818,
#  frozenset({'DU-145'}): 0.03636363636363636,
#  frozenset({'DNA-PCR'}): 0.01818181818181818,
#  frozenset({'ZFX'}): 0.01818181818181818,
#  frozenset({'ZFY'}): 0.01818181818181818,
#  frozenset({'MMP-1'}): 0.01818181818181818,
#  frozenset({'PCR-RFLP'}): 0.01818181818181818}

# %%
C2 = createCk(L1, k=2)
C2
# Out:
# [frozenset({'CDKN2', 'DU-145'}),
#  frozenset({'DU-145', 'PC-3'}),
#  frozenset({'DU-145', 'MTS1'}),
#  frozenset({'BPH', 'DU-145'}),
#  frozenset({'DU-145', 'SICI'}),
#  frozenset({'DU-145', 'PTI-1'}),
#  frozenset({'DU-145', 'TSU-PR1'}),
#  frozenset({'DU-145', 'MXI1'}),
#  frozenset({'DU-145', 'P53'}),
#  frozenset({'DU-145', 'PCR-SSCP'}),
#  frozenset({'DU-145', 'TGF-'}),
#  frozenset({'DU-145', 'PSA'}),
#  frozenset({'DU-145', 'IL-2'}),
#  frozenset({'DU-145', 'SSCP'}),
#  frozenset({'DU-145', 'RT-PCR'}),
#  frozenset({'DU-145', 'RFLP'}),
#  frozenset({'APC', 'DU-145'}),
#  frozenset({'BRCA2', 'DU-145'}),
#  frozenset({'BRCA1', 'DU-145'}),
#  frozenset({'CDKN2', 'PC-3'}),
#  frozenset({'CDKN2', 'MTS1'}),
#  frozenset({'BPH', 'CDKN2'}),
#  frozenset({'CDKN2', 'SICI'}),
#  frozenset({'CDKN2', 'PTI-1'}),
#  frozenset({'CDKN2', 'TSU-PR1'}),
#  frozenset({'CDKN2', 'MXI1'}),
#  frozenset({'CDKN2', 'P53'}),
#  frozenset({'CDKN2', 'PCR-SSCP'}),
#  frozenset({'CDKN2', 'TGF-'}),
#  frozenset({'CDKN2', 'PSA'}),
#  frozenset({'CDKN2', 'IL-2'}),
#  frozenset({'CDKN2', 'SSCP'}),
#  frozenset({'CDKN2', 'RT-PCR'}),
#  frozenset({'CDKN2', 'RFLP'}),
#  frozenset({'APC', 'CDKN2'}),
#  frozenset({'BRCA2', 'CDKN2'}),
#  frozenset({'BRCA1', 'CDKN2'}),
#  frozenset({'MTS1', 'PC-3'}),
#  frozenset({'BPH', 'PC-3'}),
#  frozenset({'PC-3', 'SICI'}),
#  frozenset({'PC-3', 'PTI-1'}),
#  frozenset({'PC-3', 'TSU-PR1'}),
#  frozenset({'MXI1', 'PC-3'}),
#  frozenset({'P53', 'PC-3'}),
#  frozenset({'PC-3', 'PCR-SSCP'}),
#  frozenset({'PC-3', 'TGF-'}),
#  frozenset({'PC-3', 'PSA'}),
#  frozenset({'IL-2', 'PC-3'}),
#  frozenset({'PC-3', 'SSCP'}),
#  frozenset({'PC-3', 'RT-PCR'}),
#  frozenset({'PC-3', 'RFLP'}),
#  frozenset({'APC', 'PC-3'}),
#  frozenset({'BRCA2', 'PC-3'}),
#  frozenset({'BRCA1', 'PC-3'}),
#  frozenset({'BPH', 'MTS1'}),
#  frozenset({'MTS1', 'SICI'}),
#  frozenset({'MTS1', 'PTI-1'}),
#  frozenset({'MTS1', 'TSU-PR1'}),
#  frozenset({'MTS1', 'MXI1'}),
#  frozenset({'MTS1', 'P53'}),
#  frozenset({'MTS1', 'PCR-SSCP'}),
#  frozenset({'MTS1', 'TGF-'}),
#  frozenset({'MTS1', 'PSA'}),
#  frozenset({'IL-2', 'MTS1'}),
#  frozenset({'MTS1', 'SSCP'}),
#  frozenset({'MTS1', 'RT-PCR'}),
#  frozenset({'MTS1', 'RFLP'}),
#  frozenset({'APC', 'MTS1'}),
#  frozenset({'BRCA2', 'MTS1'}),
#  frozenset({'BRCA1', 'MTS1'}),
#  frozenset({'BPH', 'SICI'}),
#  frozenset({'BPH', 'PTI-1'}),
#  frozenset({'BPH', 'TSU-PR1'}),
#  frozenset({'BPH', 'MXI1'}),
#  frozenset({'BPH', 'P53'}),
#  frozenset({'BPH', 'PCR-SSCP'}),
#  frozenset({'BPH', 'TGF-'}),
#  frozenset({'BPH', 'PSA'}),
#  frozenset({'BPH', 'IL-2'}),
#  frozenset({'BPH', 'SSCP'}),
#  frozenset({'BPH', 'RT-PCR'}),
#  frozenset({'BPH', 'RFLP'}),
#  frozenset({'APC', 'BPH'}),
#  frozenset({'BPH', 'BRCA2'}),
#  frozenset({'BPH', 'BRCA1'}),
#  frozenset({'PTI-1', 'SICI'}),
#  frozenset({'SICI', 'TSU-PR1'}),
#  frozenset({'MXI1', 'SICI'}),
#  frozenset({'P53', 'SICI'}),
#  frozenset({'PCR-SSCP', 'SICI'}),
#  frozenset({'SICI', 'TGF-'}),
#  frozenset({'PSA', 'SICI'}),
#  frozenset({'IL-2', 'SICI'}),
#  frozenset({'SICI', 'SSCP'}),
#  frozenset({'RT-PCR', 'SICI'}),
#  frozenset({'RFLP', 'SICI'}),
#  frozenset({'APC', 'SICI'}),
#  frozenset({'BRCA2', 'SICI'}),
#  frozenset({'BRCA1', 'SICI'}),
#  frozenset({'PTI-1', 'TSU-PR1'}),
#  frozenset({'MXI1', 'PTI-1'}),
#  frozenset({'P53', 'PTI-1'}),
#  frozenset({'PCR-SSCP', 'PTI-1'}),
#  frozenset({'PTI-1', 'TGF-'}),
#  frozenset({'PSA', 'PTI-1'}),
#  frozenset({'IL-2', 'PTI-1'}),
#  frozenset({'PTI-1', 'SSCP'}),
#  frozenset({'PTI-1', 'RT-PCR'}),
#  frozenset({'PTI-1', 'RFLP'}),
#  frozenset({'APC', 'PTI-1'}),
#  frozenset({'BRCA2', 'PTI-1'}),
#  frozenset({'BRCA1', 'PTI-1'}),
#  frozenset({'MXI1', 'TSU-PR1'}),
#  frozenset({'P53', 'TSU-PR1'}),
#  frozenset({'PCR-SSCP', 'TSU-PR1'}),
#  frozenset({'TGF-', 'TSU-PR1'}),
#  frozenset({'PSA', 'TSU-PR1'}),
#  frozenset({'IL-2', 'TSU-PR1'}),
#  frozenset({'SSCP', 'TSU-PR1'}),
#  frozenset({'RT-PCR', 'TSU-PR1'}),
#  frozenset({'RFLP', 'TSU-PR1'}),
#  frozenset({'APC', 'TSU-PR1'}),
#  frozenset({'BRCA2', 'TSU-PR1'}),
#  frozenset({'BRCA1', 'TSU-PR1'}),
#  frozenset({'MXI1', 'P53'}),
#  frozenset({'MXI1', 'PCR-SSCP'}),
#  frozenset({'MXI1', 'TGF-'}),
#  frozenset({'MXI1', 'PSA'}),
#  frozenset({'IL-2', 'MXI1'}),
#  frozenset({'MXI1', 'SSCP'}),
#  frozenset({'MXI1', 'RT-PCR'}),
#  frozenset({'MXI1', 'RFLP'}),
#  frozenset({'APC', 'MXI1'}),
#  frozenset({'BRCA2', 'MXI1'}),
#  frozenset({'BRCA1', 'MXI1'}),
#  frozenset({'P53', 'PCR-SSCP'}),
#  frozenset({'P53', 'TGF-'}),
#  frozenset({'P53', 'PSA'}),
#  frozenset({'IL-2', 'P53'}),
#  frozenset({'P53', 'SSCP'}),
#  frozenset({'P53', 'RT-PCR'}),
#  frozenset({'P53', 'RFLP'}),
#  frozenset({'APC', 'P53'}),
#  frozenset({'BRCA2', 'P53'}),
#  frozenset({'BRCA1', 'P53'}),
#  frozenset({'PCR-SSCP', 'TGF-'}),
#  frozenset({'PCR-SSCP', 'PSA'}),
#  frozenset({'IL-2', 'PCR-SSCP'}),
#  frozenset({'PCR-SSCP', 'SSCP'}),
#  frozenset({'PCR-SSCP', 'RT-PCR'}),
#  frozenset({'PCR-SSCP', 'RFLP'}),
#  frozenset({'APC', 'PCR-SSCP'}),
#  frozenset({'BRCA2', 'PCR-SSCP'}),
#  frozenset({'BRCA1', 'PCR-SSCP'}),
#  frozenset({'PSA', 'TGF-'}),
#  frozenset({'IL-2', 'TGF-'}),
#  frozenset({'SSCP', 'TGF-'}),
#  frozenset({'RT-PCR', 'TGF-'}),
#  frozenset({'RFLP', 'TGF-'}),
#  frozenset({'APC', 'TGF-'}),
#  frozenset({'BRCA2', 'TGF-'}),
#  frozenset({'BRCA1', 'TGF-'}),
#  frozenset({'IL-2', 'PSA'}),
#  frozenset({'PSA', 'SSCP'}),
#  frozenset({'PSA', 'RT-PCR'}),
#  frozenset({'PSA', 'RFLP'}),
#  frozenset({'APC', 'PSA'}),
#  frozenset({'BRCA2', 'PSA'}),
#  frozenset({'BRCA1', 'PSA'}),
#  frozenset({'IL-2', 'SSCP'}),
#  frozenset({'IL-2', 'RT-PCR'}),
#  frozenset({'IL-2', 'RFLP'}),
#  frozenset({'APC', 'IL-2'}),
#  frozenset({'BRCA2', 'IL-2'}),
#  frozenset({'BRCA1', 'IL-2'}),
#  frozenset({'RT-PCR', 'SSCP'}),
#  frozenset({'RFLP', 'SSCP'}),
#  frozenset({'APC', 'SSCP'}),
#  frozenset({'BRCA2', 'SSCP'}),
#  frozenset({'BRCA1', 'SSCP'}),
#  frozenset({'RFLP', 'RT-PCR'}),
#  frozenset({'APC', 'RT-PCR'}),
#  frozenset({'BRCA2', 'RT-PCR'}),
#  frozenset({'BRCA1', 'RT-PCR'}),
#  frozenset({'APC', 'RFLP'}),
#  frozenset({'BRCA2', 'RFLP'}),
#  frozenset({'BRCA1', 'RFLP'}),
#  frozenset({'APC', 'BRCA2'}),
#  frozenset({'APC', 'BRCA1'}),
#  frozenset({'BRCA1', 'BRCA2'})]

# %%
L2, support_data2 = scanD(D, C2, min_support)

# %%
L2
# Out:
# [frozenset({'CDKN2', 'MTS1'}), frozenset({'BPH', 'RT-PCR'})]

# %%
support_data2
# Out:
# {frozenset({'BRCA1', 'BRCA2'}): 0.01818181818181818,
#  frozenset({'RT-PCR', 'SSCP'}): 0.01818181818181818,
#  frozenset({'RFLP', 'SSCP'}): 0.01818181818181818,
#  frozenset({'APC', 'SSCP'}): 0.01818181818181818,
#  frozenset({'BRCA1', 'SSCP'}): 0.01818181818181818,
#  frozenset({'RFLP', 'RT-PCR'}): 0.01818181818181818,
#  frozenset({'APC', 'RT-PCR'}): 0.01818181818181818,
#  frozenset({'BRCA1', 'RT-PCR'}): 0.01818181818181818,
#  frozenset({'APC', 'RFLP'}): 0.01818181818181818,
#  frozenset({'BRCA1', 'RFLP'}): 0.01818181818181818,
#  frozenset({'APC', 'BRCA1'}): 0.01818181818181818,
#  frozenset({'APC', 'PSA'}): 0.01818181818181818,
#  frozenset({'P53', 'RFLP'}): 0.01818181818181818,
#  frozenset({'IL-2', 'PSA'}): 0.01818181818181818,
#  frozenset({'APC', 'PCR-SSCP'}): 0.01818181818181818,
#  frozenset({'P53', 'PCR-SSCP'}): 0.01818181818181818,
#  frozenset({'P53', 'SSCP'}): 0.01818181818181818,
#  frozenset({'PCR-SSCP', 'SSCP'}): 0.01818181818181818,
#  frozenset({'BPH', 'RT-PCR'}): 0.03636363636363636,
#  frozenset({'MTS1', 'SSCP'}): 0.01818181818181818,
#  frozenset({'PC-3', 'SICI'}): 0.01818181818181818,
#  frozenset({'PC-3', 'TSU-PR1'}): 0.01818181818181818,
#  frozenset({'PC-3', 'RT-PCR'}): 0.01818181818181818,
#  frozenset({'SICI', 'TSU-PR1'}): 0.01818181818181818,
#  frozenset({'RT-PCR', 'SICI'}): 0.01818181818181818,
#  frozenset({'RT-PCR', 'TSU-PR1'}): 0.01818181818181818,
#  frozenset({'PTI-1', 'RT-PCR'}): 0.01818181818181818,
#  frozenset({'CDKN2', 'MTS1'}): 0.03636363636363636,
#  frozenset({'CDKN2', 'PCR-SSCP'}): 0.01818181818181818,
#  frozenset({'MTS1', 'PCR-SSCP'}): 0.01818181818181818,
#  frozenset({'DU-145', 'PC-3'}): 0.01818181818181818,
#  frozenset({'DU-145', 'PSA'}): 0.01818181818181818,
#  frozenset({'PC-3', 'PSA'}): 0.01818181818181818,
#  frozenset({'BPH', 'DU-145'}): 0.01818181818181818,
#  frozenset({'DU-145', 'RT-PCR'}): 0.01818181818181818}

# %%
C3 = createCk(L2, k=3)
C3
# Out:
# []

# %%
L3, support_data3 = scanD(D, C3, min_support)

# %%
L3
# Out:
# []

# %%
support_data3
# Out:
# {frozenset({'ABSTRACT', 'TRUNCATED', 'WORDS'}): 0.03636363636363636}

# %%
C4 = createCk(L3, k=4)
C4
# Out:
# []

# %%
L4, support_data4 = scanD(D, C4, min_support)

# %%
L4
# Out:
# []

# %%
support_data4
# Out:
# {}

# %%
C5= createCk(L4, k=5)

# %%
C5
# Out:
# []
